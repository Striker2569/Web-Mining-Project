# %%
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from wordcloud import WordCloud
import os
import spacy
nlp = spacy.load('en_core_web_sm')
from textblob import TextBlob
from pattern.en import sentiment

# %%
# !pip install pattern --user
# Out:
# Collecting pattern
#   Downloading Pattern-3.6.0.tar.gz (22.2 MB)
#      -------------------------------------- 22.2/22.2 MB 293.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ------------------------------------ 840.9/840.9 kB 479.0 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting backports.csv
#   Using cached backports.csv-1.0.7-py2.py3-none-any.whl (12 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.1.1-cp310-cp310-win_amd64.whl (178 kB)
#      ------------------------------------ 178.4/178.4 kB 299.3 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from pattern) (4.9.3)
# Requirement already satisfied: lxml in c:\python310\lib\site-packages (from pattern) (4.9.2)
# Requirement already satisfied: feedparser in c:\python310\lib\site-packages (from pattern) (6.0.10)
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 209.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from pattern) (1.23.1)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from pattern) (1.9.0)
# Requirement already satisfied: nltk in c:\users\harsh\appdata\roaming\python\python310\site-packages (from pattern) (3.8.1)
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 321.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cherrypy
#   Downloading CherryPy-18.8.0-py2.py3-none-any.whl (348 kB)
#      ------------------------------------ 348.4/348.4 kB 515.6 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\harsh\appdata\roaming\python\python310\site-packages (from pattern) (2.25.1)
# Requirement already satisfied: soupsieve>1.2 in c:\python310\lib\site-packages (from beautifulsoup4->pattern) (2.3.2.post1)
# Collecting cheroot>=8.2.1
#   Downloading cheroot-9.0.0-py2.py3-none-any.whl (100 kB)
#      ------------------------------------ 100.6/100.6 kB 578.9 kB/s eta 0:00:00
# Collecting portend>=2.1.1
#   Downloading portend-3.1.0-py3-none-any.whl (5.3 kB)
# Collecting zc.lockfile
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting jaraco.collections
#   Downloading jaraco.collections-4.0.0-py3-none-any.whl (10 kB)
# Collecting more-itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      -------------------------------------- 54.2/54.2 kB 467.7 kB/s eta 0:00:00
# Requirement already satisfied: sgmllib3k in c:\python310\lib\site-packages (from feedparser->pattern) (1.0.0)
# Requirement already satisfied: click in c:\python310\lib\site-packages (from nltk->pattern) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from nltk->pattern) (2022.10.31)
# Requirement already satisfied: joblib in c:\python310\lib\site-packages (from nltk->pattern) (1.1.0)
# Requirement already satisfied: tqdm in c:\python310\lib\site-packages (from nltk->pattern) (4.64.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from pdfminer.six->pattern) (2.1.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from pdfminer.six->pattern) (39.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from requests->pattern) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in c:\python310\lib\site-packages (from requests->pattern) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\python310\lib\site-packages (from requests->pattern) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python310\lib\site-packages (from requests->pattern) (1.26.12)
# Collecting jaraco.functools
#   Downloading jaraco.functools-3.6.0-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\harsh\appdata\roaming\python\python310\site-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.1)
# Collecting tempora>=1.8
#   Downloading tempora-5.2.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from click->nltk->pattern) (0.4.6)
# Collecting jaraco.text
#   Downloading jaraco.text-3.11.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in c:\users\harsh\appdata\roaming\python\python310\site-packages (from zc.lockfile->cherrypy->pattern) (67.6.0)
# Requirement already satisfied: pycparser in c:\python310\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: pytz in c:\python310\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2022.1)
# Collecting autocommand
#   Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Collecting jaraco.context>=4.1
#   Downloading jaraco.context-4.3.0-py3-none-any.whl (5.3 kB)
# Collecting inflect
#   Downloading inflect-6.0.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: pydantic>=1.9.1 in c:\python310\lib\site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (1.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\python310\lib\site-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (4.3.0)
# Building wheels for collected packages: pattern, future, python-docx
#   Building wheel for pattern (setup.py): started
#   Building wheel for pattern (setup.py): finished with status 'done'
#   Created wheel for pattern: filename=Pattern-3.6-py3-none-any.whl size=22332702 sha256=7d48afaf63f2cf4af806660f15e4f812b64869b1675fc005dfb414e62479fa6e
#   Stored in directory: c:\users\harsh\appdata\local\pip\cache\wheels\d1\8f\40\fe23abd593ef60be5bfaf3e02154d3484df42aa947bbf4d499
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492025 sha256=faf0112e38b301f893a17b4e87823aa221fe61b9d66c78d453b302d4709f8838
#   Stored in directory: c:\users\harsh\appdata\local\pip\cache\wheels\5e\a9\47\f118e66afd12240e4662752cc22cefae5d97275623aa8ef57d
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184489 sha256=444962452a686385e36b1b5bb440df08a3f5de404978516dc720e2b6b13d03a0
#   Stored in directory: c:\users\harsh\appdata\local\pip\cache\wheels\80\27\06\837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built pattern future python-docx
# Installing collected packages: backports.csv, zc.lockfile, python-docx, mysqlclient, more-itertools, jaraco.context, future, autocommand, jaraco.functools, inflect, tempora, pdfminer.six, jaraco.text, cheroot, portend, jaraco.collections, cherrypy, pattern
# Successfully installed autocommand-2.2.2 backports.csv-1.0.7 cheroot-9.0.0 cherrypy-18.8.0 future-0.18.3 inflect-6.0.2 jaraco.collections-4.0.0 jaraco.context-4.3.0 jaraco.functools-3.6.0 jaraco.text-3.11.1 more-itertools-9.1.0 mysqlclient-2.1.1 pattern-3.6 pdfminer.six-20221105 portend-3.1.0 python-docx-0.8.11 tempora-5.2.1 zc.lockfile-3.0.post1
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
